# %%
print("Task 1")
name = "Yevheniia"
day = "Monday"
print("Варіант 1_(+)")
print("Good day "+name+"!"+day+" is a perfect day to learn some python.\n")

print("Варіант 2_(.format())")
print("Good day {}! {} is a perfect day to learn some python.\n".format(name, day))

print("Варіант 3_(f-string)")
print(f"Good day {name}! {day} is a perfect day to learn some python.\n")
# Out:
# Task 1
# Варіант 1_(+)
# Good day Yevheniia!Monday is a perfect day to learn some python.
#
# Варіант 2_(.format())
# Good day Yevheniia! Monday is a perfect day to learn some python.
#
# Варіант 3_(f-string)
# Good day Yevheniia! Monday is a perfect day to learn some python.

# %%
print("Task 2")
first_name="Yevheniia"
last_name="Khodakivska"
full_name=first_name+" "+last_name
print("Hello, "+full_name+"!\n")
# Out:
# Task 2
# Hello, Yevheniia Khodakivska!

# %%
print("Task 3")
a = 10
b = 3

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Division:", a / b)
print("Multiplication:", a * b)
print("Exponent (Power):", a ** b)
print("Modulus:", a % b)
print("Floor division:", a // b)


a = float(input("Enter first number: "))
b = float(input("Enter second number: "))

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Division:", a / b)
print("Multiplication:", a * b)
print("Exponent (Power):", a ** b)
print("Modulus:", a % b)
print("Floor division:", a // b)
# Out:
# Task 3
# Addition: 13
# Subtraction: 7
# Division: 3.3333333333333335
# Multiplication: 30
# Exponent (Power): 1000
# Modulus: 1
# Floor division: 3
# Addition: 25.0
# Subtraction: 21.0
# Division: 11.5
# Multiplication: 46.0
# Exponent (Power): 529.0
# Modulus: 1.0
# Floor division: 11.0
